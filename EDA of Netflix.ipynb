# %%
import pandas as pd
import seaborn  as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("C:\\Users\\bipin\\Desktop\\AITASK2\\all-weeks-global.csv", encoding='ISO-8859-1')
df
# Out:
#             week          category  weekly_rank  \
# 0     2024-01-07   Films (English)            1
# 1     2024-01-07   Films (English)            2
# 2     2024-01-07   Films (English)            3
# 3     2024-01-07   Films (English)            4
# 4     2024-01-07   Films (English)            5
# ...          ...               ...          ...
# 5275  2021-07-04  TV (Non-English)            6
# 5276  2021-07-04  TV (Non-English)            7
# 5277  2021-07-04  TV (Non-English)            8
# 5278  2021-07-04  TV (Non-English)            9
# 5279  2021-07-04  TV (Non-English)           10
#
#                                   show_title                  season_title  \
# 0                            The Equalizer 3                           NaN
# 1     Rebel Moon ? Part One: A Child of Fire                           NaN
# 2                     Leave the World Behind                           NaN
# 3                     Exodus: Gods and Kings                           NaN
# ...

# %%
# Categorical data
# countplot
sns.countplot(data=df, x='category')
df['cumulative_weeks_in_top_10'].value_counts()
# Out:
# cumulative_weeks_in_top_10
# 1     1898
# 2     1266
# 3      719
# 4      430
# 5      272
# 6      177
# 7      119
# 8       88
# 9       56
# 10      47
# 11      37
# 12      28
# 13      26
# 14      20
# 15      16
# 16      14
# 18      10
# 17      10
# 19       9
# 20       8
# 21       7
# 22       5
# 23       4
# 25       3
# 24       3
# 28       2
# 27       2
# 26       2
# 30       1
# 29       1
# Name: count, dtype: int64

# %%
df['category'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# Numberical Value

# Histogram treat as categorical data distribution of data

plt.hist(df['weekly_hours_viewed'])
# Out:
# (array([5.014e+03, 2.040e+02, 3.700e+01, 1.100e+01, 5.000e+00, 5.000e+00,
#         0.000e+00, 3.000e+00, 0.000e+00, 1.000e+00]),
#  array([7.00000e+05, 5.78060e+07, 1.14912e+08, 1.72018e+08, 2.29124e+08,
#         2.86230e+08, 3.43336e+08, 4.00442e+08, 4.57548e+08, 5.14654e+08,
#         5.71760e+08]),
#  <BarContainer object of 10 artists>)

# %%
# Distplot
# probability density function --> The line is kde
# skweness
sns.distplot(df['weekly_views'])
# Out:
# C:\Users\bipin\AppData\Local\Temp\ipykernel_18072\3049110407.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['weekly_views'])
# <Axes: xlabel='weekly_views', ylabel='Density'>

# %%
# Boxplot
# 5 number summary
# median , percentile, min=Q1-1.5*IQR, max=Q3+1.5*IQR, IQR = (Q1-Q3), outlier

sns.boxplot(df['runtime'])
# Out:
# <Axes: >

# %%
df = df.fillna(0) # This will fill NaN values with 0

# Step 2: Ensure columns are numeric
numerical_columns = ['weekly_hours_viewed', 'runtime', 'weekly_hours_viewed']
df_numeric = df.select_dtypes(include=[np.number]).columns.intersection(numerical_columns)

# Create a pair plot
sns.pairplot(df[df_numeric], height=2, diag_kind='kde')

# Set title
plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()
# Out:
# E:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
